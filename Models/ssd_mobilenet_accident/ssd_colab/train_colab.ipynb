# %% [markdown]
# # SSD Accident Detection — Colab Training
# Chạy từng cell theo thứ tự.

# %%
# Cell 1 — Cài thư viện
# !pip install torch torchvision tqdm --quiet

# %%
# Cell 2 — Upload dataset lên Colab
# Nén thư mục ssd_dataset thành ssd_dataset.zip rồi upload
from google.colab import files
uploaded = files.upload()   # chọn file ssd_dataset.zip

import zipfile, os
with zipfile.ZipFile('ssd_dataset.zip', 'r') as z:
    z.extractall('/content/')

print('Dataset đã giải nén vào /content/ssd_dataset')
print(os.listdir('/content/ssd_dataset'))

# %%
# Cell 3 — Upload 4 file code
# Upload: config.py, dataset.py, train_ssd.py, detect_ssd.py
from google.colab import files
files.upload()

# %%
# Cell 4 — Kiểm tra GPU
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %%
# Cell 5 — Bắt đầu train
# !python train_ssd.py

# %%
# Cell 6 — Download model sau khi train xong
from google.colab import files
files.download('/content/ssd_accident_best.pth')
